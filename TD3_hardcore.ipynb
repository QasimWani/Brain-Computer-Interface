# %% [markdown]
# <a href="https://colab.research.google.com/github/QasimWani/Brain-Computer-Interface/blob/master/TD3_hardcore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gym==0.15.4
# !pip install box2d-py
import gym
print(gym.__version__)
# Out:
# Requirement already satisfied: gym==0.15.4 in /usr/local/lib/python3.6/dist-packages (0.15.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (from gym==0.15.4) (4.1.2.30)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym==0.15.4) (1.4.1)
# Requirement already satisfied: pyglet<=1.3.2,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.15.4) (1.3.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym==0.15.4) (1.18.5)
# Requirement already satisfied: cloudpickle~=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.15.4) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym==0.15.4) (1.15.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.3.2,>=1.2.0->gym==0.15.4) (0.16.0)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.6/dist-packages (2.3.8)
# 0.15.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/My\ Drive/TD3
# Out:
# /content/drive/My Drive/TD3

# %%
ls
# Out:
# models/

# %%
import numpy as np
from collections import deque, namedtuple
import torch
import random


#Implemented from: https://github.com/QasimWani/policy-value-methods/blob/master/DDPG/ddpg_agent.py#L150

#Set to cuda (gpu) instance if compute available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


BUFFER_SIZE = 50_000 #max number of experiences in a buffer
MINI_BATCH = 100 #number of samples to collect from buffer

class ReplayBuffer():
    """
    Implementation of a fixed size replay buffer as used in DQN algorithms.
    The goal of a replay buffer is to unserialize relationships between sequential experiences, gaining a better temporal understanding.
    """
    def __init__(self, buffer_size=BUFFER_SIZE, batch_size=MINI_BATCH):
        """
        Initializes the buffer.
        @Param:
        1. action_size: env.action_space.shape[0]
        2. buffer_size: Maximum length of the buffer for extrapolating all experiences into trajectories. default - 1e6 (Source: DeepMind)
        3. batch_size: size of mini-batch to train on. default = 64.
        """
        self.replay_memory = deque(maxlen=buffer_size) #Experience replay memory object
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"]) #standard S,A,R,S',done
        
    def add(self, state, action, reward, next_state, done):
        """Adds an experience to existing memory"""
        trajectory = self.experience(state, action, reward, next_state, done)
        self.replay_memory.append(trajectory)
    
    def sample(self):
        """Randomly picks minibatches within the replay_buffer of size mini_batch"""
        experiences = random.sample(self.replay_memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).float().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return states, actions, rewards, next_states, dones

    def __len__(self):#override default __len__ operator
        """Return the current size of internal memory."""
        return len(self.replay_memory)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

#Twin Delayed Deep Deterministic Policy Gradient (TD3) implementation for continuous action space control.
#Paper: https://arxiv.org/pdf/1802.09477.pdf
#Author: https://github.com/sfujim/TD3


class Actor(nn.Module):
    def __init__(self, state_size, action_size, max_action, fc1=256, fc2=256):
        """
        Initializes actor object.
        @Param:
        1. state_size: env.observation_space.shape[0].
        2. action_size: env.action_space.shape[0].
        3. max_action: abs(env.action_space.low), sets boundary/clip for policy approximation.
        4. fc1: number of hidden units for the first fully connected layer, fc1. Default = 256.
        5. fc2: number of hidden units for the second fully connected layer, fc1. Default = 256.
        """
        super(Actor, self).__init__()

        #Layer 1
        self.fc1 = nn.Linear(state_size, fc1)
        #Layer 2
        self.fc2 = nn.Linear(fc1, fc2)
        #Layer 3
        self.mu = nn.Linear(fc2, action_size)

        #Define boundary for action space.
        self.max_action = max_action
    
    def forward(self, state):
        """Peforms forward pass to map state--> pi(s)"""
        #Layer 1
        x = self.fc1(state)
        x = F.relu(x)
        #Layer 2
        x = self.fc2(x)
        x = F.relu(x)
        #Output layer
        mu = torch.tanh(self.mu(x))#set action b/w -1 and +1
        return self.max_action * mu


class Critic(nn.Module):
    def __init__(self, state_size, action_size, fc1=256, fc2=256):
        """
        Initializes Critic object, Q1 and Q2.
        Architecture different from DDPG. See paper for full details.
        @Param:
        1. state_size: env.observation_space.shape[0].
        2. action_size: env.action_space.shape[0].
        3. fc1: number of hidden units for the first fully connected layer, fc1. Default = 256.
        4. fc2: number of hidden units for the second fully connected layer, fc1. Default = 256.
        """
        super(Critic, self).__init__()

        #---------Q1 architecture---------
        
        #Layer 1
        self.l1 = nn.Linear(state_size + action_size, fc1)
        #Layer 2
        self.l2 = nn.Linear(fc1, fc2)
        #Output layer
        self.l3 = nn.Linear(fc2, 1)#Q-value

        #---------Q2 architecture---------

        #Layer 1
        self.l4 = nn.Linear(state_size + action_size, fc1)
        #Layer 2
        self.l5 = nn.Linear(fc1, fc2)
        #Output layer
        self.l6 = nn.Linear(fc2, 1)#Q-value
    
    def forward(self, state, action):
        """Perform forward pass by mapping (state, action) --> Q-value"""
        x = torch.cat([state, action], dim=1) #concatenate state and action such that x.shape = state.shape + action.shape

        #---------Q1 critic forward pass---------
        #Layer 1
        q1 = F.relu(self.l1(x))
        #Layer 2
        q1 = F.relu(self.l2(q1))
        #value prediction for Q1
        q1 = self.l3(q1)

        #---------Q2 critic forward pass---------
        #Layer 1
        q2 = F.relu(self.l4(x))
        #Layer 2
        q2 = F.relu(self.l5(q2))
        #value prediction for Q2
        q2 = self.l6(q2)

        return q1, q2

# %%
import random
import copy

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim


#implementation from paper: https://arxiv.org/pdf/1802.09477.pdf
#source: https://github.com/sfujim/TD3/blob/master/TD3.py

#Set to cuda (gpu) instance if compute available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


class Agent():
    """Agent that plays and learn from experience. Hyper-paramters chosen from paper."""
    def __init__(
            self, 
            state_size, 
            action_size, 
            max_action, 
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
        ):
        """
        Initializes the Agent.
        @Param:
        1. state_size: env.observation_space.shape[0]
        2. action_size: env.action_size.shape[0]
        3. max_action: list of max values that the agent can take, i.e. abs(env.action_space.high)
        4. discount: return rate
        5. tau: soft target update
        6. policy_noise: noise reset level, DDPG uses Ornstein-Uhlenbeck process
        7. noise_clip: sets boundary for noise calculation to prevent from overestimation of Q-values
        8. policy_freq: number of timesteps to update the policy (actor) after
        """
        super(Agent, self).__init__()

        #Actor Network initialization
        self.actor = Actor(state_size, action_size, max_action).to(device)
        self.actor.apply(self.init_weights)
        self.actor_target = copy.deepcopy(self.actor) #loads main model into target model
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=0.001)

        #Critic Network initialization
        self.critic = Critic(state_size, action_size).to(device)
        self.critic.apply(self.init_weights)
        self.critic_target = copy.deepcopy(self.critic) #loads main model into target model
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=0.001)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq
        self.total_it = 0

    def init_weights(self, layer):
        """Xaviar Initialization of weights"""
        if(type(layer) == nn.Linear):
          nn.init.xavier_normal_(layer.weight)
          layer.bias.data.fill_(0.01)

    def select_action(self, state):
        """Selects an automatic epsilon-greedy action based on the policy"""
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()
    
    def train(self, replay_buffer:ReplayBuffer):
        """Train the Agent"""

        self.total_it += 1

        # Sample replay buffer 
        state, action, reward, next_state, done = replay_buffer.sample()#sample 256 experiences

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)
            

            next_action = (
                self.actor_target(next_state) + noise #noise only set in training to prevent from overestimation
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action) #Q1, Q2
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + (1 - done) * self.discount * target_Q #TD-target

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action) #Q1, Q2

        # Compute critic loss using MSE
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates (DDPG baseline = 1)
        if(self.total_it % self.policy_freq == 0):

            # Compute actor loss
            actor_loss = -self.critic(state, self.actor(state))[0].mean()
            
            # Optimize the actor 
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Soft update by updating the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)


    def save(self, filename):
        """Saves the Actor Critic local and target models"""
        torch.save(self.critic.state_dict(), "models/checkpoint/"+ filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), "models/checkpoint/" + filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), "models/checkpoint/" + filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), "models/checkpoint/" + filename + "_actor_optimizer")


    def load(self, filename):
        """Loads the Actor Critic local and target models"""
        self.critic.load_state_dict(torch.load("models/checkpoint/" + filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load("models/checkpoint/" + filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load("models/checkpoint/" + filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load("models/checkpoint/" + filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
import numpy as np
import torch
import gym
import random
import matplotlib.pyplot as plt

env_id = "BipedalWalkerHardcore-v2"
env = gym.make(env_id)


#set seeds
random_seed = 0
env.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
random.seed(random_seed)


#Set exploration noise for calculating action based on some noise factor
exploration_noise = 0.1

#Define observation and action space
state_space = env.observation_space.shape[0]
action_space = env.action_space.shape[0] 
max_action = float(env.action_space.high[0])

#Create Agent
policy = Agent(state_space, action_space, max_action)

try:
    policy.load("10")
except:
    raise IOError("Couldn't load policy")

#Create Replay Buffer
replay_buffer = ReplayBuffer()


#Train the model
max_episodes = 4000
max_timesteps = 2000

ep_reward = [] #get list of reward for range(max_episodes)
for episode in range(1, max_episodes+1):
    avg_reward = 0
    state = env.reset()
    for t in range(1, max_timesteps + 1):
        # select action and add exploration noise:
        action = policy.select_action(state) + np.random.normal(0, max_action * exploration_noise, size=action_space)
        action = action.clip(env.action_space.low, env.action_space.high)
            
        # take action in env:
        next_state, reward, done, _ = env.step(action)
        replay_buffer.add(state, action, reward, next_state, done)
        state = next_state
            
        avg_reward += reward

        #Renders an episode
        # env.render()
        if(len(replay_buffer) > 100):#make sure sample is less than overall population
            policy.train(replay_buffer) #training mode

        # if episode is done then update policy:
        if(done or t >=max_timesteps):
            print(f"Episode {episode} reward: {avg_reward} | Rolling average: {np.mean(ep_reward)}")
            print(f"Current time step: {t}")
            ep_reward.append(avg_reward)
            break 
    
    if(np.mean(ep_reward[-10:]) >= 300):
          policy.save("final")
          break

    if(episode % 100 == 0 and episode > 0):
        #Save policy and optimizer every 100 episodes
        policy.save(str("%02d" % (10 + episode//100)))

env.close()

#Display Scores
fig = plt.figure()
plt.plot(np.arange(1, len(ep_reward) + 1), ep_reward)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1 reward: 278.6319873150503 | Rolling average: 11.957914667508769
# Current time step: 1003
# Episode 2 reward: 281.09091634779793 | Rolling average: 12.224322332491319
# Current time step: 1006
# Episode 3 reward: 278.7814908592027 | Rolling average: 12.492652266638334
# Current time step: 947
# Episode 4 reward: -92.99673376451352 | Rolling average: 12.758144628146376
# Current time step: 91
# Episode 5 reward: -99.67014823549228 | Rolling average: 12.652811083930578
# Current time step: 66
# Episode 6 reward: -100.92514606531014 | Rolling average: 12.541046945304288
# Current time step: 73
# Episode 7 reward: 278.6490207358228 | Rolling average: 12.428257489031305
# Current time step: 1006
# Episode 8 reward: 286.9157988867283 | Rolling average: 12.692627661073805
# Current time step: 905
# Episode 9 reward: -116.7291510712499 | Rolling average: 12.964674457924657
# Current time step: 261
# Episode 10 reward: 1.7800628604821043 | Rolling average: 12.836137465328843
# Current time step: 404
# Episode 11 reward: 278.66771282638734 | Rolling average: 12.825190856809185
# Current time step: 986
# Episode 12 reward: 285.97195620947474 | Rolling average: 13.088140927995722
# Current time step: 898
# Episode 13 reward: 279.5050391619435 | Rolling average: 13.357788966811407
# Current time step: 1007
# Episode 14 reward: 278.8550294901473 | Rolling average: 13.620520704417657
# Current time step: 979
# Episode 15 reward: 118.5332257159873 | Rolling average: 13.882093198289189
# Current time step: 850
# Episode 16 reward: 290.5339613170294 | Rolling average: 13.985197762346038
# Current time step: 850
# Episode 17 reward: 285.56708054075114 | Rolling average: 14.257391427262057
# Current time step: 958
# Episode 18 reward: 286.48404830376677 | Rolling average: 14.524165949497549
# Current time step: 936
# Episode 19 reward: 286.1273213163648 | Rolling average: 14.791317110945753
# Current time step: 901
# Episode 20 reward: 287.49925525752013 | Rolling average: 15.057593856976588
# Current time step: 922
# Episode 21 reward: 285.9477881168672 | Rolling average: 15.324693525016329
# Current time step: 912
# Episode 22 reward: -105.00064161549722 | Rolling average: 15.589750424714522
# Current time step: 55
# Episode 23 reward: 283.4168998053557 | Rolling average: 15.471755911955023
# Current time step: 953
# Episode 24 reward: 121.72036537443537 | Rolling average: 15.733676873727648
# Current time step: 768
# Episode 25 reward: -35.052695246345095 | Rolling average: 15.83717949921661
# Current time step: 287
# Episode 26 reward: 287.95184499391763 | Rolling average: 15.787530840928262
# Current time step: 888
# Episode 27 reward: -68.87164593291297 | Rolling average: 16.052798203650475
# Current time step: 318
# Episode 28 reward: 292.1023637724092 | Rolling average: 15.97010643720786
# Current time step: 857
# Episode 29 reward: -69.10791855069289 | Rolling average: 16.238717582475573
# Current time step: 181
# Episode 30 reward: -68.92588217383948 | Rolling average: 16.155776245125548
# Current time step: 298
# Episode 31 reward: -20.655128059636127 | Rolling average: 16.073172693262467
# Current time step: 359
# Episode 32 reward: -61.14959234287165 | Rolling average: 16.037548735209224
# Current time step: 267
# Episode 33 reward: 286.0518763643168 | Rolling average: 15.962754993854492
# Current time step: 935
# Episode 34 reward: 280.77145417360174 | Rolling average: 16.224215905152136
# Current time step: 997
# Episode 35 reward: -41.36450054191388 | Rolling average: 16.480064298061667
# Current time step: 271
# Episode 36 reward: 284.4682034863907 | Rolling average: 16.424175829617248
# Current time step: 952
# Episode 37 reward: 289.59415876154907 | Rolling average: 16.68290558604271
# Current time step: 879
# Episode 38 reward: 286.84244034184485 | Rolling average: 16.946079407812714
# Current time step: 903
# Episode 39 reward: -100.82895789746958 | Rolling average: 17.206095169791553
# Current time step: 164
# Episode 40 reward: -110.43322325392829 | Rolling average: 17.09249069138226
# Current time step: 120
# Episode 41 reward: 287.6854290560807 | Rolling average: 16.969869812588694
# Current time step: 876
# Episode 42 reward: 286.3988502140731 | Rolling average: 17.2299231836199
# Current time step: 955
# Episode 43 reward: 287.92431535295657 | Rolling average: 17.48824269132667
# Current time step: 918
# Episode 44 reward: 287.0619647098574 | Rolling average: 17.74752943405115
# Current time step: 981
# Episode 45 reward: 289.12536341064504 | Rolling average: 18.005493452514564
# Current time step: 914
# Episode 46 reward: 290.1153032166345 | Rolling average: 18.264938304149133
# Current time step: 911
# Episode 47 reward: 289.10578770196383 | Rolling average: 18.524833490489947
# Current time step: 883
# Episode 48 reward: 283.9975156296427 | Rolling average: 18.783268021733004
# Current time step: 923
# Episode 49 reward: 155.61029985446714 | Rolling average: 19.036335051893214
# Current time step: 896
# Episode 50 reward: 281.93551358600894 | Rolling average: 19.16652948926459
# Current time step: 887
# Episode 51 reward: 113.65982919334533 | Rolling average: 19.416785664594826
# Current time step: 929
# Episode 52 reward: 285.0894029348173 | Rolling average: 19.506455544260614
# Current time step: 892
# Episode 53 reward: 288.9077258953939 | Rolling average: 19.758910817445564
# Current time step: 836
# Episode 54 reward: 280.59682965779336 | Rolling average: 20.014512731099835
# Current time step: 891
# Episode 55 reward: 285.17556165247026 | Rolling average: 20.261744530840527
# Current time step: 866
# Episode 56 reward: 289.27770538003165 | Rolling average: 20.51284767503165
# Current time step: 816
# Episode 57 reward: -114.77644010504207 | Rolling average: 20.767359850888663
# Current time step: 86
# Episode 58 reward: 283.8286075253266 | Rolling average: 20.639125413844255
# Current time step: 878
# Episode 59 reward: 285.93488565034613 | Rolling average: 20.887886739091403
# Current time step: 822
# Episode 60 reward: 284.6005391484358 | Rolling average: 21.138167191321106
# Current time step: 857
# Episode 61 reward: 278.73447558915876 | Rolling average: 21.386716598827817
# Current time step: 888
# Episode 62 reward: 286.2291743147875 | Rolling average: 21.629268680816814
# Current time step: 832
# Episode 63 reward: 270.6282349819973 | Rolling average: 21.878421134332804
# Current time step: 996
# Episode 64 reward: 285.2256955887828 | Rolling average: 22.11242848508319
# Current time step: 816
# Episode 65 reward: 279.5586891466789 | Rolling average: 22.359715390255843
# Current time step: 910
# Episode 66 reward: 254.87379397135308 | Rolling average: 22.601216774064692
# Current time step: 1178
# Episode 67 reward: 282.34476829945635 | Rolling average: 22.8191084975143
# Current time step: 878
# Episode 68 reward: 282.8212663002471 | Rolling average: 23.06233779442334
# Current time step: 879
# Episode 69 reward: 133.64437199680808 | Rolling average: 23.305557764934413
# Current time step: 789
# Episode 70 reward: 31.191357638849667 | Rolling average: 23.40877461641418
# Current time step: 472
# Episode 71 reward: 287.3168382295203 | Rolling average: 23.416048058491224
# Current time step: 823
# Episode 72 reward: 287.0255782409293 | Rolling average: 23.662454025037473
# Current time step: 836
# Episode 73 reward: 284.83964631576026 | Rolling average: 23.908128581209006
# Current time step: 867
# Episode 74 reward: -129.09568608710887 | Rolling average: 24.151308001278487
# Current time step: 131
# Episode 75 reward: 284.46640300707725 | Rolling average: 24.008619924846098
# Current time step: 873
# Episode 76 reward: 288.231529266161 | Rolling average: 24.25090623469003
# Current time step: 818
# Episode 77 reward: 290.5020291582219 | Rolling average: 24.49624138620627
# Current time step: 790
# Episode 78 reward: 286.8866491741047 | Rolling average: 24.743229118585116
# Current time step: 834
# Episode 79 reward: 33.56655753025717 | Rolling average: 24.98640483292233
# Current time step: 501
# Episode 80 reward: 291.2901270094879 | Rolling average: 24.994356781668703
# Current time step: 798
# Episode 81 reward: 275.37552129429173 | Rolling average: 25.240926939287057
# Current time step: 983
# Episode 82 reward: -1.0530705124954522 | Rolling average: 25.472318793454498
# Current time step: 390
# Episode 83 reward: 286.7219456846846 | Rolling average: 25.44780364622164
# Current time step: 853
# Episode 84 reward: 287.80172700540913 | Rolling average: 25.68905400821469
# Current time step: 828
# Episode 85 reward: 293.93382473068897 | Rolling average: 25.930855367068187
# Current time step: 751
# Episode 86 reward: 290.3724931112773 | Rolling average: 26.177862712103785
# Current time step: 792
# Episode 87 reward: 292.0619209544309 | Rolling average: 26.421135852434507
# Current time step: 781
# Episode 88 reward: 291.6449504602435 | Rolling average: 26.665515599538466
# Current time step: 785
# Episode 89 reward: 292.7949050626702 | Rolling average: 26.909062874226613
# Current time step: 769
# Episode 90 reward: 284.08129852112273 | Rolling average: 27.153218835832156
# Current time step: 832
# Episode 91 reward: 290.8566981662449 | Rolling average: 27.38893267040582
# Current time step: 790
# Episode 92 reward: 290.45977625140426 | Rolling average: 27.630424664444167
# Current time step: 773
# Episode 93 reward: 291.60133533029585 | Rolling average: 27.87111088384615
# Current time step: 776
# Episode 94 reward: 288.2162951701498 | Rolling average: 28.11240111664253
# Current time step: 806
# Episode 95 reward: 282.792678960028 | Rolling average: 28.350156047221603
# Current time step: 846
# Episode 96 reward: 282.69779381892766 | Rolling average: 28.58252364805522
# Current time step: 825
# Episode 97 reward: 288.64489308901886 | Rolling average: 28.814380646386308
# Current time step: 778
# Episode 98 reward: 283.52059909203365 | Rolling average: 29.051236172769748
# Current time step: 828
# Episode 99 reward: 287.13249059615845 | Rolling average: 29.2829933338984
# Current time step: 801
# Episode 100 reward: 178.1975202006363 | Rolling average: 29.51761526043367
# Current time step: 808
# Episode 101 reward: -0.8932236479432589 | Rolling average: 29.652778810379306
# Current time step: 321
# Episode 102 reward: 286.2468565826556 | Rolling average: 29.625034938936686
# Current time step: 812
# Episode 103 reward: 276.66226238810447 | Rolling average: 29.85790410558253
# Current time step: 889
# Episode 104 reward: 24.638853050521917 | Rolling average: 30.081661456699965
# Current time step: 408
# Episode 105 reward: 283.81263929256346 | Rolling average: 30.076731376621904
# Current time step: 806
# Episode 106 reward: 285.3466174790841 | Rolling average: 30.30635663265443
# Current time step: 799
# Episode 107 reward: 53.40912653931733 | Rolling average: 30.536953613528233
# Current time step: 501
# Episode 108 reward: 283.11310774767634 | Rolling average: 30.557615016351896
# Current time step: 820
# Episode 109 reward: 283.64744997843565 | Rolling average: 30.785553186687025
# Current time step: 836
# Episode 110 reward: 284.1823879810414 | Rolling average: 31.013562110755316
# Current time step: 838
# Episode 111 reward: 285.2175957828134 | Rolling average: 31.24164213406188
# Current time step: 819
# Episode 112 reward: 286.15740459031167 | Rolling average: 31.470243352467598
# Current time step: 810
# Episode 113 reward: 287.1040052110402 | Rolling average: 31.69927856940812
# Current time step: 786
# Episode 114 reward: 286.6519717397457 | Rolling average: 31.928752717334106
# Current time step: 787
# Episode 115 reward: 285.8926527409935 | Rolling average: 32.157409107838966
# Current time step: 788
# Episode 116 reward: 282.0865987525761 | Rolling average: 32.38497434876556
# Current time step: 822
# Episode 117 reward: 281.11700743421727 | Rolling average: 32.60872132403779
# Current time step: 831
# Episode 118 reward: 276.6913845809605 | Rolling average: 32.83119964642829
# Current time step: 896
# Episode 119 reward: -45.0651662691002 | Rolling average: 33.049321457639856
# Current time step: 280
# Episode 120 reward: 274.987146355318 | Rolling average: 32.979514051271
# Current time step: 915
# Episode 121 reward: 281.88164185300127 | Rolling average: 33.19559229439962
# Current time step: 855
# Episode 122 reward: -68.9315506279802 | Rolling average: 33.41743533593271
# Current time step: 178
# Episode 123 reward: 287.6003944820562 | Rolling average: 33.32621520584009
# Current time step: 793
# Episode 124 reward: 288.4122370498165 | Rolling average: 33.5526392301288
# Current time step: 793
# Episode 125 reward: 286.69599255024144 | Rolling average: 33.77938264455912
# Current time step: 815
# Episode 126 reward: 285.29959603111496 | Rolling average: 34.00419740891974
# Current time step: 801
# Episode 127 reward: 286.2722653429792 | Rolling average: 34.22737271853092
# Current time step: 795
# Episode 128 reward: 284.48731908453556 | Rolling average: 34.4510150367425
# Current time step: 813
# Episode 129 reward: 276.37715649097964 | Rolling average: 34.672678426855796
# Current time step: 907
# Episode 130 reward: 277.4639707133253 | Rolling average: 34.886765652776184
# Current time step: 917
# Episode 131 reward: 281.8977199085022 | Rolling average: 35.10143574575012
# Current time step: 858
# Episode 132 reward: 282.0243912636216 | Rolling average: 35.319646430244156
# Current time step: 847
# Episode 133 reward: 281.9122326284102 | Rolling average: 35.537583483983894
# Current time step: 852
# Episode 134 reward: 286.96987475780026 | Rolling average: 35.755036837156375
# Current time step: 774
# Episode 135 reward: 281.9996402102638 | Rolling average: 35.97656667659257
# Current time step: 832
# Episode 136 reward: 285.7808322245227 | Rolling average: 36.19332709380284
# Current time step: 807
# Episode 137 reward: 287.4318724295382 | Rolling average: 36.41303440465737
# Current time step: 796
# Episode 138 reward: 284.44303211633104 | Rolling average: 36.63380734927027
# Current time step: 819
# Episode 139 reward: 284.00403902614613 | Rolling average: 36.85156589475979
# Current time step: 844
# Episode 140 reward: 281.9296081594938 | Rolling average: 37.06855665255731
# Current time step: 854
# Episode 141 reward: 283.0779357774374 | Rolling average: 37.28334704861603
# Current time step: 845
# Episode 142 reward: 285.37211262319073 | Rolling average: 37.49876737177888
# Current time step: 797
# Episode 143 reward: 287.52691914247237 | Rolling average: 37.71581933784842
# Current time step: 784
# Episode 144 reward: 284.2662405526393 | Rolling average: 37.93437673050339
# Current time step: 798
# Episode 145 reward: 280.73093750179135 | Rolling average: 38.14970178629196
# Current time step: 856
# Episode 146 reward: 280.66987229024835 | Rolling average: 38.361563127528214
# Current time step: 868
# Episode 147 reward: 285.8988867999277 | Rolling average: 38.57300144267893
# Current time step: 816
# Episode 148 reward: 24.451370387972162 | Rolling average: 38.788629939067114
# Current time step: 399
# Episode 149 reward: 278.79730192858034 | Rolling average: 38.776141037019116
# Current time step: 875
# Episode 150 reward: 278.8359435009204 | Rolling average: 38.98503673840429
# Current time step: 884
# Episode 151 reward: 280.046085547452 | Rolling average: 39.19360274428474
# Current time step: 894
# Episode 152 reward: 281.3415380771014 | Rolling average: 39.40285772499991
# Current time step: 866
# Episode 153 reward: 284.1079796786231 | Rolling average: 39.61287394058334
# Current time step: 834
# Episode 154 reward: 285.7223804903379 | Rolling average: 39.82492520314885
# Current time step: 819
# Episode 155 reward: 288.61184870720183 | Rolling average: 40.0380079200355
# Current time step: 783
# Episode 156 reward: 285.299080384837 | Rolling average: 40.25322336660447
# Current time step: 816
# Episode 157 reward: 282.3120408167168 | Rolling average: 40.46520075156835
# Current time step: 841
# Episode 158 reward: 279.7767115369722 | Rolling average: 40.674229999679966
# Current time step: 873
# Episode 159 reward: 273.5001515848651 | Rolling average: 40.880708826568814
# Current time step: 955
# Episode 160 reward: 287.21601844547274 | Rolling average: 41.08141585224466
# Current time step: 786
# Episode 161 reward: 271.3992502389362 | Rolling average: 41.2936008544802
# Current time step: 964
# Episode 162 reward: -137.856954038955 | Rolling average: 41.4917969349147
# Current time step: 137
# Episode 163 reward: 281.5850827827717 | Rolling average: 41.33745205455853
# Current time step: 842
# Episode 164 reward: 284.7978056610684 | Rolling average: 41.54402783334461
# Current time step: 831
# Episode 165 reward: 279.94893142953475 | Rolling average: 41.75300874213132
# Current time step: 888
# Episode 166 reward: 283.7518783400619 | Rolling average: 41.95746876160548
# Current time step: 842
# Episode 167 reward: 268.641993791392 | Rolling average: 42.164839610300554
# Current time step: 995
# Episode 168 reward: 285.58947263355367 | Rolling average: 42.358907437362326
# Current time step: 840
# Episode 169 reward: 282.763328132745 | Rolling average: 42.567152784276885
# Current time step: 860
# Episode 170 reward: 284.63980417096997 | Rolling average: 42.772624277303805
# Current time step: 820
# Episode 171 reward: 285.7906937831689 | Rolling average: 42.979348362683
# Current time step: 813
# Episode 172 reward: 284.73842624295963 | Rolling average: 43.18670220164157
# Current time step: 825
# Episode 173 reward: 281.41850430572714 | Rolling average: 43.392804355260445
# Current time step: 860
# Episode 174 reward: 284.3326297703846 | Rolling average: 43.59572481557627
# Current time step: 840
# Episode 175 reward: 289.31706362952747 | Rolling average: 43.80078180446451
# Current time step: 780
# Episode 176 reward: 281.48399957199285 | Rolling average: 44.00973183154968
# Current time step: 872
# Episode 177 reward: 284.188171894876 | Rolling average: 44.211665732689504
# Current time step: 838
# Episode 178 reward: 283.410948167494 | Rolling average: 44.41555401320115
# Current time step: 860
# Episode 179 reward: 285.5016136567038 | Rolling average: 44.61843635119289
# Current time step: 818
# Episode 180 reward: 283.80983654038863 | Rolling average: 44.82274778232566
# Current time step: 834
# Episode 181 reward: 284.647671103327 | Rolling average: 45.025279213476544
# Current time step: 828
# Episode 182 reward: 281.832203225099 | Rolling average: 45.228177089759235
# Current time step: 834
# Episode 183 reward: 282.2410415257231 | Rolling average: 45.42834970070283
# Current time step: 841
# Episode 184 reward: 285.85703615357846 | Rolling average: 45.62852949091841
# Current time step: 800
# Episode 185 reward: 284.9199825362513 | Rolling average: 45.83142518911323
# Current time step: 794
# Episode 186 reward: 282.4770150448181 | Rolling average: 46.03318768476482
# Current time step: 824
# Episode 187 reward: 278.17521345676516 | Rolling average: 46.23255010243771
# Current time step: 875
# Episode 188 reward: 280.06375611294743 | Rolling average: 46.42795251469915
# Current time step: 844
# Episode 189 reward: 282.74216107270564 | Rolling average: 46.624615649041104
# Current time step: 833
# Episode 190 reward: 281.93343058251247 | Rolling average: 46.823200632576565
# Current time step: 835
# Episode 191 reward: 97.354029332555 | Rolling average: 47.02077225438324
# Current time step: 595
# Episode 192 reward: 270.60573863234816 | Rolling average: 47.063033595338894
# Current time step: 968
# Episode 193 reward: 280.98105055563093 | Rolling average: 47.250569421712214
# Current time step: 849
# Episode 194 reward: -10.204019775485108 | Rolling average: 47.44648767915892
# Current time step: 323
# Episode 195 reward: 284.55250578477546 | Rolling average: 47.39820417207798
# Current time step: 815
# Episode 196 reward: 283.2454887126586 | Rolling average: 47.596659654599065
# Current time step: 844
# Episode 197 reward: 279.0648735792983 | Rolling average: 47.79369044812587
# Current time step: 909
# Episode 198 reward: 12.552379709653081 | Rolling average: 47.986899456589676
# Current time step: 497
# Episode 199 reward: -105.65498936250137 | Rolling average: 47.957321393361845
# Current time step: 131
# Episode 200 reward: 280.51336088797825 | Rolling average: 47.829204370212665
# Current time step: 894
# Episode 201 reward: 280.15283274310906 | Rolling average: 48.023107833977484
# Current time step: 909
# Episode 202 reward: -8.020266480351125 | Rolling average: 48.21638820442638
# Current time step: 378
# Episode 203 reward: 273.609866622944 | Rolling average: 48.1696023020264
# Current time step: 949
# Episode 204 reward: 267.26223056270874 | Rolling average: 48.35700069298311
# Current time step: 971
# Episode 205 reward: 274.98066067269014 | Rolling average: 48.538815667957955
# Current time step: 891
# Episode 206 reward: 279.8708509969215 | Rolling average: 48.72673421153035
# Current time step: 858
# Episode 207 reward: 280.9100349064232 | Rolling average: 48.91839599990962
# Current time step: 811
# Episode 208 reward: 278.8400192032299 | Rolling average: 49.11060116884625
# Current time step: 849
# Episode 209 reward: 280.7934057348306 | Rolling average: 49.30077452814624
# Current time step: 838
# Episode 210 reward: 282.74121446130476 | Rolling average: 49.49224899564557
# Current time step: 824
# Episode 211 reward: 281.25121778636384 | Rolling average: 49.685016735699826
# Current time step: 844
# Episode 212 reward: 276.28644578388605 | Rolling average: 49.87623572913556
# Current time step: 891
# Episode 213 reward: 280.36159536374464 | Rolling average: 50.06304283314113
# Current time step: 834
# Episode 214 reward: 137.82130081317 | Rolling average: 50.2529014914516
# Current time step: 875
# Episode 215 reward: 279.6544532499655 | Rolling average: 50.32503361609882
# Current time step: 858
# Episode 216 reward: 283.9074550210941 | Rolling average: 50.51378210962463
# Current time step: 808
# Episode 217 reward: 282.39080670566625 | Rolling average: 50.705717695900496
# Current time step: 828
# Episode 218 reward: 284.6378803625929 | Rolling average: 50.89609163921172
# Current time step: 823
# Episode 219 reward: 283.42405680134345 | Rolling average: 51.08799786969069
# Current time step: 832
# Episode 220 reward: -79.80109879283438 | Rolling average: 51.2785934881744
# Current time step: 121
# Episode 221 reward: -31.564293610210086 | Rolling average: 51.17115111745228
# Current time step: 251
# Episode 222 reward: 283.4956930438503 | Rolling average: 51.10339072045992
# Current time step: 816
# Episode 223 reward: 277.2045247877386 | Rolling average: 51.29356445394879
# Current time step: 906
# Episode 224 reward: 282.9735199731822 | Rolling average: 51.478283145963324
# Current time step: 817
# Episode 225 reward: 280.2417357311798 | Rolling average: 51.667413241410415
# Current time step: 847
# Episode 226 reward: 280.5377737126532 | Rolling average: 51.85400452507552
# Current time step: 830
# Episode 227 reward: 278.898444247136 | Rolling average: 52.04053288493488
# Current time step: 877
# Episode 228 reward: 281.4986915953066 | Rolling average: 52.22542115825371
# Current time step: 863
# Episode 229 reward: 283.84160462369346 | Rolling average: 52.41212577587346
# Current time step: 840
# Episode 230 reward: 279.30168112649403 | Rolling average: 52.6004329189555
# Current time step: 901
# Episode 231 reward: 279.193189808115 | Rolling average: 52.784742876847794
# Current time step: 917
# Episode 232 reward: 281.5371313944415 | Rolling average: 52.968665254533654
# Current time step: 867
# Episode 233 reward: 277.9553309921041 | Rolling average: 53.15419160691994
# Current time step: 900
# Episode 234 reward: 278.36302834501043 | Rolling average: 53.33651207681871
# Current time step: 864
# Episode 235 reward: 272.8154559063142 | Rolling average: 53.5188674384623
# Current time step: 961
# Episode 236 reward: 262.6819243070101 | Rolling average: 53.69643552629052
# Current time step: 1070
# Episode 237 reward: 278.9471778007098 | Rolling average: 53.86551763695453
# Current time step: 883
# Episode 238 reward: 276.7356518203703 | Rolling average: 54.047475325041646
# Current time step: 884
# Episode 239 reward: 279.7650233148367 | Rolling average: 54.22735268893125
# Current time step: 883
# Episode 240 reward: 283.7075057289342 | Rolling average: 54.40938470719267
# Current time step: 854
# Episode 241 reward: 279.3680590020874 | Rolling average: 54.59430254672633
# Current time step: 877
# Episode 242 reward: 275.87098818019876 | Rolling average: 54.77542563814886
# Current time step: 941
# Episode 243 reward: 273.34201234541905 | Rolling average: 54.95344138898787
# Current time step: 944
# Episode 244 reward: 278.07163754959095 | Rolling average: 55.129136136338175
# Current time step: 893
# Episode 245 reward: 281.3944057318934 | Rolling average: 55.308350365770046
# Current time step: 883
# Episode 246 reward: 276.9587180086905 | Rolling average: 55.48994559096372
# Current time step: 938
# Episode 247 reward: 253.72349756971335 | Rolling average: 55.66768938905178
# Current time step: 1185
# Episode 248 reward: 287.10017714047956 | Rolling average: 55.82651521758479
# Current time step: 849
# Episode 249 reward: 286.2359424852709 | Rolling average: 56.011830651817874
# Current time step: 851
# Episode 250 reward: 285.48450400277244 | Rolling average: 56.19615740268534
# Current time step: 872
# Episode 251 reward: 284.5168242990895 | Rolling average: 56.37958807996541
# Current time step: 874
# Episode 252 reward: 285.28486915308576 | Rolling average: 56.56195197782242
# Current time step: 855
# Episode 253 reward: 286.37634955678186 | Rolling average: 56.7446380139049
# Current time step: 868
# Episode 254 reward: 287.5249087679404 | Rolling average: 56.9279035458625
# Current time step: 870
# Episode 255 reward: 283.1076009294986 | Rolling average: 57.11179270473178
# Current time step: 880
# Episode 256 reward: 278.43721211970905 | Rolling average: 57.29186904594673
# Current time step: 930
# Episode 257 reward: 279.90226928534275 | Rolling average: 57.46794017896724
# Current time step: 937
# Episode 258 reward: 286.4526065734942 | Rolling average: 57.644896685814004
# Current time step: 872
# Episode 259 reward: -3.3289504592743526 | Rolling average: 57.826778808141256
# Current time step: 374
# Episode 260 reward: -45.59265497818684 | Rolling average: 57.77820396360796
# Current time step: 283
# Episode 261 reward: 288.2954389885031 | Rolling average: 57.69616359936843
# Current time step: 825
# Episode 262 reward: 285.70487037009974 | Rolling average: 57.87903376224642
# Current time step: 876
# Episode 263 reward: 288.1915540137538 | Rolling average: 58.05956136653157
# Current time step: 831
# Episode 264 reward: 282.3602520145436 | Rolling average: 58.241771970369435
# Current time step: 920
# Episode 265 reward: 280.3448579391802 | Rolling average: 58.41908089445501
# Current time step: 916
# Episode 266 reward: 286.2005561933336 | Rolling average: 58.594516291328326
# Current time step: 853
# Episode 267 reward: 286.60091067379864 | Rolling average: 58.774299893146654
# Current time step: 833
# Episode 268 reward: 273.2515530597971 | Rolling average: 58.9541156869751
# Current time step: 992
# Episode 269 reward: 282.37673251402634 | Rolling average: 59.12311997512401
# Current time step: 897
# Episode 270 reward: 104.2008704352424 | Rolling average: 59.29904874781031
# Current time step: 1273
# Episode 271 reward: 240.93019278913619 | Rolling average: 59.3344045129185
# Current time step: 1329
# Episode 272 reward: 274.92720280671404 | Rolling average: 59.47728082155441
# Current time step: 992
# Episode 273 reward: 250.61750800099867 | Rolling average: 59.646659691039574
# Current time step: 1246
# Episode 274 reward: 283.6295345009108 | Rolling average: 59.796676068345135
# Current time step: 882
# Episode 275 reward: 283.944050885559 | Rolling average: 59.97236904984634
# Current time step: 869
# Episode 276 reward: 285.76444813764743 | Rolling average: 60.148033114031215
# Current time step: 835
# Episode 277 reward: 287.036198723833 | Rolling average: 60.32484848630679
# Current time step: 824
# Episode 278 reward: 285.7448197480825 | Rolling average: 60.50238282478566
# Current time step: 829
# Episode 279 reward: 288.51102078834725 | Rolling average: 60.67862886306679
# Current time step: 800
# Episode 280 reward: 286.9194920515713 | Rolling average: 60.85676208583873
# Current time step: 823
# Episode 281 reward: 286.218308620284 | Rolling average: 61.03337359362447
# Current time step: 816
# Episode 282 reward: 275.66912871171354 | Rolling average: 61.20916198942982
# Current time step: 903
# Episode 283 reward: 282.72560914294684 | Rolling average: 61.376447454891824
# Current time step: 839
# Episode 284 reward: 274.8306418955086 | Rolling average: 61.548972132746904
# Current time step: 941
# Episode 285 reward: -43.277128282272045 | Rolling average: 61.715079352188305
# Current time step: 214
# Episode 286 reward: 280.08929618098057 | Rolling average: 61.63337335402919
# Current time step: 869
# Episode 287 reward: 282.76385703131916 | Rolling average: 61.80324576680287
# Current time step: 843
# Episode 288 reward: 270.7409427406725 | Rolling average: 61.97493233344196
# Current time step: 990
# Episode 289 reward: 277.4076979144408 | Rolling average: 62.13701774524881
# Current time step: 923
# Episode 290 reward: 278.6633339921691 | Rolling average: 62.30402370348713
# Current time step: 900
# Episode 291 reward: 281.3244191823708 | Rolling average: 62.471744099059755
# Current time step: 887
# Episode 292 reward: 282.7902876887764 | Rolling average: 62.641265923291606
# Current time step: 875
# Episode 293 reward: 69.76811088457276 | Rolling average: 62.81165990298626
# Current time step: 583
# Episode 294 reward: 275.46389358057206 | Rolling average: 62.81703998881887
# Current time step: 923
# Episode 295 reward: 81.79381769349297 | Rolling average: 62.9813729514091
# Current time step: 673
# Episode 296 reward: 281.8109772991878 | Rolling average: 62.99589993576592
# Current time step: 857
# Episode 297 reward: 282.02090293711683 | Rolling average: 63.16473873002782
# Current time step: 856
# Episode 298 reward: 280.909816314518 | Rolling average: 63.33347902625534
# Current time step: 886
# Episode 299 reward: 284.4892568336582 | Rolling average: 63.5011033230876
# Current time step: 845
# Episode 300 reward: 283.44421414285983 | Rolling average: 63.671225073288184
# Current time step: 846
# Episode 301 reward: 286.2319534256437 | Rolling average: 63.84028121872632
# Current time step: 809
# Episode 302 reward: 286.1576654645158 | Rolling average: 64.01122024425047
# Current time step: 817
# Episode 303 reward: 284.83314895587006 | Rolling average: 64.18183963382056
# Current time step: 829
# Episode 304 reward: 283.56319091986063 | Rolling average: 64.35118062332327
# Current time step: 836
# Episode 305 reward: 282.26059392558085 | Rolling average: 64.51928799318259
# Current time step: 855
# Episode 306 reward: 288.64165259912596 | Rolling average: 64.68613956860972
# Current time step: 794
# Episode 307 reward: 283.0817992165866 | Rolling average: 64.8576215847127
# Current time step: 866
# Episode 308 reward: 284.4838555186981 | Rolling average: 65.02458729062845
# Current time step: 859
# Episode 309 reward: 283.80265192853426 | Rolling average: 65.19236960578752
# Current time step: 847
# Episode 310 reward: 284.54009207803654 | Rolling average: 65.35937516905929
# Current time step: 843
# Episode 311 reward: 286.3184311650066 | Rolling average: 65.5266886934173
# Current time step: 824
# Episode 312 reward: 285.46479790500575 | Rolling average: 65.6951034474002
# Current time step: 839
# Episode 313 reward: 281.8589603444592 | Rolling average: 65.86261083646849
# Current time step: 871
# Episode 314 reward: 283.86012826931847 | Rolling average: 66.02711681476856
# Current time step: 833
# Episode 315 reward: 287.85866990168034 | Rolling average: 66.19289536229867
# Current time step: 799
# Episode 316 reward: 290.3374071492199 | Rolling average: 66.36146249122595
# Current time step: 820
# Episode 317 reward: 285.68761753692627 | Rolling average: 66.53165697804815
# Current time step: 848
# Episode 318 reward: 290.5046375231394 | Rolling average: 66.69806241507082
# Current time step: 814
# Episode 319 reward: 289.1903742928129 | Rolling average: 66.86787013518318
# Current time step: 811
# Episode 320 reward: 292.48392581535626 | Rolling average: 67.03642396699335
# Current time step: 788
# Episode 321 reward: 288.1944875631916 | Rolling average: 67.20721752899969
# Current time step: 833
# Episode 322 reward: 292.5923387744144 | Rolling average: 67.37450539427917
# Current time step: 774
# Episode 323 reward: 294.58419988535 | Rolling average: 67.54486684161664
# Current time step: 781
# Episode 324 reward: 291.1599331404876 | Rolling average: 67.71647631481673
# Current time step: 796
# Episode 325 reward: 292.221796334697 | Rolling average: 67.8852402550174
# Current time step: 802
# Episode 326 reward: 292.38273178334515 | Rolling average: 68.05455086337942
# Current time step: 821
# Episode 327 reward: 293.1334437642459 | Rolling average: 68.22372747040805
# Current time step: 813
# Episode 328 reward: 290.8578759390701 | Rolling average: 68.3932148225511
# Current time step: 811
# Episode 329 reward: 291.34795764595 | Rolling average: 68.56073339266896
# Current time step: 822
# Episode 330 reward: 286.1308933038566 | Rolling average: 68.72836862536518
# Current time step: 863
# Episode 331 reward: 288.81220301917705 | Rolling average: 68.89182917023624
# Current time step: 845
# Episode 332 reward: 290.9636115496683 | Rolling average: 69.05705860212875
# Current time step: 798
# Episode 333 reward: 292.5695097214175 | Rolling average: 69.22365511335062
# Current time step: 782
# Episode 334 reward: 290.4323304940131 | Rolling average: 69.39120639212636
# Current time step: 834
# Episode 335 reward: 293.64903050959 | Rolling average: 69.55690438620574
# Current time step: 787
# Episode 336 reward: 292.51787421935506 | Rolling average: 69.72476365671014
# Current time step: 819
# Episode 337 reward: 292.4648554101581 | Rolling average: 69.89152496701152
# Current time step: 812
# Episode 338 reward: 288.8756352070922 | Rolling average: 70.05799716629585
# Current time step: 832
# Episode 339 reward: 289.174698386097 | Rolling average: 70.22153800190183
# Current time step: 840
# Episode 340 reward: 279.7060366903803 | Rolling average: 70.38505791256965
# Current time step: 938
# Episode 341 reward: 285.69206283155825 | Rolling average: 70.54126759822472
# Current time step: 873
# Episode 342 reward: 293.89890230313114 | Rolling average: 70.7017081614114
# Current time step: 796
# Episode 343 reward: 294.8554621401182 | Rolling average: 70.8680249975826
# Current time step: 786
# Episode 344 reward: 294.625027645438 | Rolling average: 71.03480641019803
# Current time step: 796
# Episode 345 reward: 290.36436643024905 | Rolling average: 71.20116818195045
# Current time step: 838
# Episode 346 reward: 292.96116277806647 | Rolling average: 71.36411479774844
# Current time step: 837
# Episode 347 reward: 295.48346118443493 | Rolling average: 71.52874856296413
# Current time step: 797
# Episode 348 reward: 294.2200018486072 | Rolling average: 71.69501041346261
# Current time step: 803
# Episode 349 reward: 285.18646371490405 | Rolling average: 71.86008830028393
# Current time step: 891
# Episode 350 reward: 141.6891545032373 | Rolling average: 72.01822497590635
# Current time step: 654
# Episode 351 reward: 288.6750368058152 | Rolling average: 72.06983307185251
# Current time step: 850
# Episode 352 reward: 10.380568690193371 | Rolling average: 72.23016260829513
# Current time step: 351
# Episode 353 reward: 295.1473743413263 | Rolling average: 72.18441586723144
# Current time step: 776
# Episode 354 reward: 288.9843389580021 | Rolling average: 72.34920741081909
# Current time step: 846
# Episode 355 reward: 295.5384731261003 | Rolling average: 72.5092038152114
# Current time step: 778
# Episode 356 reward: 293.27035429196405 | Rolling average: 72.6738010619353
# Current time step: 786
# Episode 357 reward: 296.9127844043246 | Rolling average: 72.83648288585125
# Current time step: 763
# Episode 358 reward: 7.542868782231878 | Rolling average: 73.0016091213107
# Current time step: 348
# Episode 359 reward: 19.834883742980153 | Rolling average: 72.95340680883714
# Current time step: 347
# Episode 360 reward: 256.08555529601546 | Rolling average: 72.91432033123166
# Current time step: 1205
# Episode 361 reward: 281.1425238428096 | Rolling average: 73.0490050628234
# Current time step: 938
# Episode 362 reward: 295.28918075928954 | Rolling average: 73.20190257845896
# Current time step: 761
# Episode 363 reward: 296.4226524428543 | Rolling average: 73.36496225406897
# Current time step: 739
# Episode 364 reward: 296.5801572284918 | Rolling average: 73.52861426447895
# Current time step: 750
# Episode 365 reward: 295.82775667695563 | Rolling average: 73.6921417886461
# Current time step: 769
# Episode 366 reward: 295.2224327070236 | Rolling average: 73.85487850284999
# Current time step: 753
# Episode 367 reward: 294.51840307849307 | Rolling average: 74.01693381339476
# Current time step: 772
# Episode 368 reward: 294.5859416268737 | Rolling average: 74.17823700963844
# Current time step: 764
# Episode 369 reward: 296.389356760703 | Rolling average: 74.3393537527797
# Current time step: 756
# Episode 370 reward: 298.42010275669276 | Rolling average: 74.50155244014853
# Current time step: 741
# Episode 371 reward: 297.46310358352554 | Rolling average: 74.66499663745988
# Current time step: 754
# Episode 372 reward: 294.13804786162854 | Rolling average: 74.8275043741091
# Current time step: 779
# Episode 373 reward: 294.3001370859969 | Rolling average: 74.98735170901253
# Current time step: 788
# Episode 374 reward: 297.0634865697433 | Rolling average: 75.14708425480785
# Current time step: 768
# Episode 375 reward: 297.51891861819036 | Rolling average: 75.30859546464404
# Current time step: 759
# Episode 376 reward: 294.59776104067527 | Rolling average: 75.47020297239209
# Current time step: 791
# Episode 377 reward: 292.44527896887575 | Rolling average: 75.62945265122076
# Current time step: 813
# Episode 378 reward: 290.18633496851635 | Rolling average: 75.78690786278044
# Current time step: 828
# Episode 379 reward: 290.80613312701917 | Rolling average: 75.94249525545514
# Current time step: 806
# Episode 380 reward: 292.32300691915214 | Rolling average: 76.0983064504309
# Current time step: 811
# Episode 381 reward: 293.4658025981592 | Rolling average: 76.25499101598793
# Current time step: 791
# Episode 382 reward: 294.9408458487354 | Rolling average: 76.41227618005902
# Current time step: 776
# Episode 383 reward: 293.9974036115528 | Rolling average: 76.57040104957326
# Current time step: 788
# Episode 384 reward: 290.7092151777493 | Rolling average: 76.72761507890223
# Current time step: 811
# Episode 385 reward: 291.41729788492063 | Rolling average: 76.88222606163264
# Current time step: 814
# Episode 386 reward: 291.9533476407717 | Rolling average: 77.0371250304581
# Current time step: 800
# Episode 387 reward: 289.7867742648823 | Rolling average: 77.19218724013366
# Current time step: 829
# Episode 388 reward: 287.62361083262334 | Rolling average: 77.34546379891141
# Current time step: 849
# Episode 389 reward: 291.3595016144905 | Rolling average: 77.4969610229991
# Current time step: 820
# Episode 390 reward: 293.31795368959985 | Rolling average: 77.65092973472801
# Current time step: 800
# Episode 391 reward: 294.01129254929674 | Rolling average: 77.80608586706965
# Current time step: 781
# Episode 392 reward: 297.61929107572314 | Rolling average: 77.9615173600116
# Current time step: 772
# Episode 393 reward: 293.6515527575556 | Rolling average: 78.11931748480738
# Current time step: 794
# Episode 394 reward: 297.4105432157086 | Rolling average: 78.27404270754445
# Current time step: 775
# Episode 395 reward: -16.267082216701866 | Rolling average: 78.43124249270093
# Current time step: 267
# Episode 396 reward: 296.2702851099883 | Rolling average: 78.36335838896662
# Current time step: 774
# Episode 397 reward: 296.0216965444669 | Rolling average: 78.51945217601606
# Current time step: 784
# Episode 398 reward: 292.27820954099235 | Rolling average: 78.675144548506
# Current time step: 826
# Episode 399 reward: 295.08747202327623 | Rolling average: 78.82793644048917
# Current time step: 778
# Episode 400 reward: 298.4916230624474 | Rolling average: 78.9825179526999
# Current time step: 765
# Episode 401 reward: 290.02759263406944 | Rolling average: 79.1393101706354
# Current time step: 825
# Episode 402 reward: -9.153641420104805 | Rolling average: 79.2898371388463
# Current time step: 296
# Episode 403 reward: 289.2869119236794 | Rolling average: 79.22675334529498
# Current time step: 819
# Episode 404 reward: 165.19878676939186 | Rolling average: 79.37647548255684
# Current time step: 880
# Episode 405 reward: 291.3659543674689 | Rolling average: 79.43760248489787
# Current time step: 807
# Episode 406 reward: 171.71184354292183 | Rolling average: 79.58844116951182
# Current time step: 782
# Episode 407 reward: 298.1811529282165 | Rolling average: 79.6539627928215
# Current time step: 754
# Episode 408 reward: -105.8209870167917 | Rolling average: 79.8092770715247
# Current time step: 54
# Episode 409 reward: -102.64013333350135 | Rolling average: 79.6774373953256
# Current time step: 73
# Episode 410 reward: -101.04113392437934 | Rolling average: 79.54804238416249
# Current time step: 68
# Episode 411 reward: -104.25744873564125 | Rolling average: 79.41996495415641
# Current time step: 67
# Episode 412 reward: -67.61852265439764 | Rolling average: 79.28978960781356
# Current time step: 174
# Episode 413 reward: -113.95037762688064 | Rolling average: 79.18574689374684
# Current time step: 42
# Episode 414 reward: 65.22758723250138 | Rolling average: 79.04906173838899
# Current time step: 540
# Episode 415 reward: 31.33206811411779 | Rolling average: 79.03928700394353
# Current time step: 488
# Episode 416 reward: 287.8450133385154 | Rolling average: 79.00557165490478
# Current time step: 872
# Episode 417 reward: 277.5381569169197 | Rolling average: 79.15305713631975
# Current time step: 993
# Episode 418 reward: 276.7219761028655 | Rolling average: 79.29306073531806
# Current time step: 1011
# Episode 419 reward: 62.650197256831405 | Rolling average: 79.4322912821217
# Current time step: 557
# Episode 420 reward: 294.5830583679652 | Rolling average: 79.42046457738223
# Current time step: 861
# Episode 421 reward: 82.58253238326913 | Rolling average: 79.57198753075589
# Current time step: 616
# Episode 422 reward: 282.90506474374587 | Rolling average: 79.5741061407858
# Current time step: 984
# Episode 423 reward: 293.54014958537226 | Rolling average: 79.71709556315075
# Current time step: 822
# Episode 424 reward: 124.47343381151904 | Rolling average: 79.86735772339125
# Current time step: 661
# Episode 425 reward: 288.41617674892916 | Rolling average: 79.89868221502617
# Current time step: 858
# Episode 426 reward: 283.9841530347688 | Rolling average: 80.04501028136575
# Current time step: 906
# Episode 427 reward: 285.9293295459601 | Rolling average: 80.18802510798105
# Current time step: 858
# Episode 428 reward: 279.13032031246405 | Rolling average: 80.33220261634683
# Current time step: 970
# Episode 429 reward: 289.8412161233949 | Rolling average: 80.47141698448137
# Current time step: 832
# Episode 430 reward: 289.4663848592193 | Rolling average: 80.61793188940713
# Current time step: 844
# Episode 431 reward: 289.940982500351 | Rolling average: 80.76397975861678
# Current time step: 860
# Episode 432 reward: 293.11239684539703 | Rolling average: 80.91015516234965
# Current time step: 795
# Episode 433 reward: 289.0457194751395 | Rolling average: 81.05834108531266
# Current time step: 876
# Episode 434 reward: 289.58776277444275 | Rolling average: 81.20348231238162
# Current time step: 861
# Episode 435 reward: 293.9465573192068 | Rolling average: 81.34879910489354
# Current time step: 797
# Episode 436 reward: 293.68266185844 | Rolling average: 81.49695085277807
# Current time step: 855
# Episode 437 reward: 294.6710470756157 | Rolling average: 81.64471248996865
# Current time step: 822
# Episode 438 reward: 297.0345888721073 | Rolling average: 81.79295628578328
# Current time step: 830
# Episode 439 reward: 294.616162204627 | Rolling average: 81.94263753236626
# Current time step: 847
# Episode 440 reward: 292.5477451367395 | Rolling average: 82.09043011379245
# Current time step: 895
# Episode 441 reward: 293.90850059871644 | Rolling average: 82.23658102700281
# Current time step: 827
# Episode 442 reward: 296.3800160473 | Rolling average: 82.38347340699708
# Current time step: 811
# Episode 443 reward: 295.520378165787 | Rolling average: 82.53187600244803
# Current time step: 814
# Episode 444 reward: 280.82957456158397 | Rolling average: 82.67947718204843
# Current time step: 984
# Episode 445 reward: 282.5930634374596 | Rolling average: 82.81670024117551
# Current time step: 951
# Episode 446 reward: 286.5677525292778 | Rolling average: 82.95495377971966
# Current time step: 901
# Episode 447 reward: 286.13315729137145 | Rolling average: 83.0957648438618
# Current time step: 877
# Episode 448 reward: 286.6256375207631 | Rolling average: 83.23608094092299
# Current time step: 901
# Episode 449 reward: 289.435399277692 | Rolling average: 83.3765433418759
# Current time step: 871
# Episode 450 reward: 292.5220381699564 | Rolling average: 83.51875097192134
# Current time step: 821
# Episode 451 reward: 289.23884655949604 | Rolling average: 83.66289116998895
# Current time step: 851
# Episode 452 reward: 294.8223525865483 | Rolling average: 83.8045699814221
# Current time step: 810
# Episode 453 reward: 292.5349759715337 | Rolling average: 83.94989903280305
# Current time step: 831
# Episode 454 reward: 296.03784687585744 | Rolling average: 84.09345380013873
# Current time step: 822
# Episode 455 reward: 292.61271427228104 | Rolling average: 84.23922023279053
# Current time step: 819
# Episode 456 reward: 273.63024362182085 | Rolling average: 84.38243225618537
# Current time step: 1038
# Episode 457 reward: 293.80041787774945 | Rolling average: 84.5124101486068
# Current time step: 810
# Episode 458 reward: -125.31518686561729 | Rolling average: 84.65605325617656
# Current time step: 103
# Episode 459 reward: -123.94514971788219 | Rolling average: 84.51204005993391
# Current time step: 90
# Episode 460 reward: 270.0103069719246 | Rolling average: 84.36916330203275
# Current time step: 1080
# Episode 461 reward: 270.0830091297521 | Rolling average: 84.49631477029979
# Current time step: 1034
# Episode 462 reward: -95.60053074925789 | Rolling average: 84.62334193960811
# Current time step: 107
# Episode 463 reward: 279.05357172131323 | Rolling average: 84.50006979686606
# Current time step: 963
# Episode 464 reward: 292.92886531660037 | Rolling average: 84.633052368243
# Current time step: 824
# Episode 465 reward: 287.24782602358647 | Rolling average: 84.77533092900006
# Current time step: 911
# Episode 466 reward: 122.56715987579892 | Rolling average: 84.91353741029332
# Current time step: 652
# Episode 467 reward: 291.6141166137863 | Rolling average: 84.93922200951943
# Current time step: 885
# Episode 468 reward: 170.44748015969913 | Rolling average: 85.0801046915946
# Current time step: 1600
# Episode 469 reward: 291.04510423351036 | Rolling average: 85.13825685472
# Current time step: 862
# Episode 470 reward: 291.3177567703806 | Rolling average: 85.2784248924183
# Current time step: 845
# Episode 471 reward: 289.72510601394697 | Rolling average: 85.41858770321964
# Current time step: 876
# Episode 472 reward: 146.23091910048714 | Rolling average: 85.55747724659878
# Current time step: 760
# Episode 473 reward: 288.98059897311316 | Rolling average: 85.59869561742345
# Current time step: 866
# Episode 474 reward: 290.2080015175221 | Rolling average: 85.73676887156851
# Current time step: 850
# Episode 475 reward: 289.06291858154276 | Rolling average: 85.87548748259019
# Current time step: 863
# Episode 476 reward: 292.36937582666394 | Rolling average: 86.01324167316574
# Current time step: 818
# Episode 477 reward: 289.31646866829755 | Rolling average: 86.15304935213153
# Current time step: 828
# Episode 478 reward: 282.32186667251113 | Rolling average: 86.29060075315805
# Current time step: 912
# Episode 479 reward: 294.64900865743255 | Rolling average: 86.42323354471378
# Current time step: 785
# Episode 480 reward: 292.52300219130603 | Rolling average: 86.5640217631808
# Current time step: 805
# Episode 481 reward: 288.71960525830156 | Rolling average: 86.70318323644302
# Current time step: 828
# Episode 482 reward: 292.15716115312637 | Rolling average: 86.83958865306819
# Current time step: 810
# Episode 483 reward: 290.9400791639578 | Rolling average: 86.97812952520049
# Current time step: 841
# Episode 484 reward: 290.57391637396694 | Rolling average: 87.11566286952872
# Current time step: 855
# Episode 485 reward: 293.79787690131326 | Rolling average: 87.25276411852091
# Current time step: 787
# Episode 486 reward: 286.5835632360604 | Rolling average: 87.39185173655646
# Current time step: 868
# Episode 487 reward: 285.75344976724716 | Rolling average: 87.52589730284147
# Current time step: 873
# Episode 488 reward: 289.4140767238409 | Rolling average: 87.65920433207107
# ...
# Current time step: 1393
# Episode 785 reward: 297.6407209805324 | Rolling average: 114.73136977165689
# Current time step: 831
# Episode 786 reward: 296.388031019656 | Rolling average: 114.83383999642376
# Current time step: 879
# Episode 787 reward: 298.19408640716654 | Rolling average: 114.9354940787436
# Current time step: 854
# Episode 788 reward: 296.27100076080575 | Rolling average: 115.03804505374553
# Current time step: 846
# Episode 789 reward: 294.52331349699944 | Rolling average: 115.13940576722821
# Current time step: 862
# Episode 790 reward: 295.41894670286524 | Rolling average: 115.23967625785414
# Current time step: 867
# Episode 791 reward: 290.37722189421953 | Rolling average: 115.34033506815861
# Current time step: 923
# Episode 792 reward: 296.12628163949825 | Rolling average: 115.43806643992079
# Current time step: 877
# Episode 793 reward: 295.9601344472044 | Rolling average: 115.5388969171527
# Current time step: 874
# Episode 794 reward: 295.7860640669171 | Rolling average: 115.63952225877571
# Current time step: 841
# Episode 795 reward: 295.39689845867525 | Rolling average: 115.73993839133321
# Current time step: 840
# Episode 796 reward: 294.0824304341969 | Rolling average: 115.84002583426765
# Current time step: 856
# Episode 797 reward: 297.34445834083175 | Rolling average: 115.93926993482441
# Current time step: 846
# Episode 798 reward: 293.85318208668747 | Rolling average: 116.04021884323063
# Current time step: 874
# Episode 799 reward: 293.2905933321447 | Rolling average: 116.13911370599119
# Current time step: 898
# Episode 800 reward: 294.2035805091269 | Rolling average: 116.23758590144764
# Current time step: 879
# Episode 801 reward: 295.3376219409458 | Rolling average: 116.3364558984519
# Current time step: 875
# Episode 802 reward: 294.36396255557713 | Rolling average: 116.43584577410014
# Current time step: 847
# Episode 803 reward: 140.91463211162483 | Rolling average: 116.5345850175971
# Current time step: 764
# Episode 804 reward: 292.4331382164312 | Rolling average: 116.54810695164812
# Current time step: 882
# Episode 805 reward: 292.09227280210087 | Rolling average: 116.64560419736031
# Current time step: 854
# Episode 806 reward: 291.84714366765706 | Rolling average: 116.74280456777845
# Current time step: 858
# Episode 807 reward: 292.91072061352065 | Rolling average: 116.83976156617263
# Current time step: 843
# Episode 808 reward: 294.96885489401177 | Rolling average: 116.93719983902672
# Current time step: 853
# Episode 809 reward: -46.76950782157962 | Rolling average: 117.0356686747872
# Current time step: 238
# Episode 810 reward: -50.15085263054765 | Rolling average: 116.9451185495819
# Current time step: 233
# Episode 811 reward: 291.05707481928073 | Rolling average: 116.85280033346031
# Current time step: 902
# Episode 812 reward: -87.36561908731 | Rolling average: 116.94899264405434
# Current time step: 149
# Episode 813 reward: 297.1179639536725 | Rolling average: 116.83623623581407
# Current time step: 860
# Episode 814 reward: 296.7034427530429 | Rolling average: 116.9356745853551
# Current time step: 874
# Episode 815 reward: 291.660421033374 | Rolling average: 117.03477478831411
# Current time step: 897
# Episode 816 reward: 288.7521461503543 | Rolling average: 117.13098726558412
# Current time step: 879
# Episode 817 reward: 294.63965755112685 | Rolling average: 117.22549230902288
# Current time step: 799
# Episode 818 reward: 135.32189013301885 | Rolling average: 117.32313356672354
# Current time step: 648
# Episode 819 reward: 293.7773776673617 | Rolling average: 117.33303387286561
# Current time step: 797
# Episode 820 reward: 291.1746584584588 | Rolling average: 117.43003461162016
# Current time step: 900
# Episode 821 reward: 295.0644635569137 | Rolling average: 117.52549869065687
# Current time step: 855
# Episode 822 reward: 292.8956519191507 | Rolling average: 117.62299400359825
# Current time step: 884
# Episode 823 reward: 293.3725472630696 | Rolling average: 117.71919194976488
# Current time step: 907
# Episode 824 reward: 295.09696177484346 | Rolling average: 117.81554595706783
# Current time step: 914
# Episode 825 reward: 295.3681047897884 | Rolling average: 117.91273971573986
# Current time step: 871
# Episode 826 reward: 287.0556355233026 | Rolling average: 118.0099755322188
# Current time step: 981
# Episode 827 reward: 282.2598489950808 | Rolling average: 118.10255256397733
# Current time step: 1029
# Episode 828 reward: 280.00799018303536 | Rolling average: 118.19240330094016
# Current time step: 1097
# Episode 829 reward: 286.0810245643185 | Rolling average: 118.28092386269185
# Current time step: 1019
# Episode 830 reward: 277.233016411606 | Rolling average: 118.37266804022144
# Current time step: 1152
# Episode 831 reward: 268.03812508720966 | Rolling average: 118.45947697375772
# Current time step: 1192
# Episode 832 reward: 279.6954306585821 | Rolling average: 118.54116929932486
# Current time step: 1047
# Episode 833 reward: 122.00120354969144 | Rolling average: 118.62913559919346
# Current time step: 1011
# Episode 834 reward: 272.4931029809242 | Rolling average: 118.63097524346541
# Current time step: 1072
# Episode 835 reward: 275.5143435147323 | Rolling average: 118.71486953339861
# Current time step: 1067
# Episode 836 reward: 281.5993707745951 | Rolling average: 118.80031883802059
# Current time step: 985
# Episode 837 reward: 278.02880029590466 | Rolling average: 118.88898934561132
# Current time step: 1106
# Episode 838 reward: 277.622090132938 | Rolling average: 118.97561961831153
# Current time step: 1123
# Episode 839 reward: 269.54154015867255 | Rolling average: 119.0619343465567
# Current time step: 1297
# Episode 840 reward: 276.4519666214974 | Rolling average: 119.1437612121424
# Current time step: 1174
# Episode 841 reward: 281.8911305072106 | Rolling average: 119.2292548020388
# Current time step: 1055
# Episode 842 reward: 288.83871225105406 | Rolling average: 119.3176099762404
# Current time step: 958
# Episode 843 reward: 289.42404855031765 | Rolling average: 119.4096409763896
# Current time step: 971
# Episode 844 reward: -112.96492403063827 | Rolling average: 119.50188970540422
# Current time step: 60
# Episode 845 reward: -112.17748408367106 | Rolling average: 119.37582310359508
# Current time step: 101
# Episode 846 reward: -114.0019853495737 | Rolling average: 119.25031995606811
# Current time step: 73
# Episode 847 reward: 279.63742559550946 | Rolling average: 119.12396442773353
# Current time step: 1044
# Episode 848 reward: 287.8105042144827 | Rolling average: 119.21086938775939
# Current time step: 989
# Episode 849 reward: 287.1881234751516 | Rolling average: 119.30210295638858
# Current time step: 1009
# Episode 850 reward: 262.93959937493014 | Rolling average: 119.39290123682058
# Current time step: 1392
# Episode 851 reward: 287.4262067209846 | Rolling average: 119.47049404662498
# Current time step: 1045
# Episode 852 reward: 291.22424113239595 | Rolling average: 119.56123187086828
# Current time step: 958
# Episode 853 reward: 285.76769923495664 | Rolling average: 119.65392248062072
# Current time step: 999
# Episode 854 reward: 291.45952879879707 | Rolling average: 119.74356833963547
# Current time step: 926
# Episode 855 reward: 292.36822872841327 | Rolling average: 119.83618752003416
# Current time step: 886
# Episode 856 reward: 292.1308525105334 | Rolling average: 119.92919670666942
# Current time step: 881
# Episode 857 reward: 287.30723235310785 | Rolling average: 120.0219777712189
# Current time step: 965
# Episode 858 reward: 290.1337073979566 | Rolling average: 120.11206137627109
# Current time step: 955
# Episode 859 reward: 292.38072882377355 | Rolling average: 120.20356925895227
# Current time step: 898
# Episode 860 reward: 289.81687241032904 | Rolling average: 120.29618741901942
# Current time step: 876
# Episode 861 reward: 290.35030614474914 | Rolling average: 120.38732757224057
# Current time step: 912
# Episode 862 reward: 287.2527389937654 | Rolling average: 120.47865641618066
# Current time step: 890
# Episode 863 reward: 290.44811724793186 | Rolling average: 120.56822359264554
# Current time step: 876
# Episode 864 reward: 289.83845708233497 | Rolling average: 120.6594097942855
# Current time step: 890
# Episode 865 reward: 291.1825632275568 | Rolling average: 120.75017108574905
# Current time step: 936
# Episode 866 reward: 288.6627164687921 | Rolling average: 120.84155574641488
# Current time step: 935
# Episode 867 reward: 117.4617609585078 | Rolling average: 120.93149205977093
# Current time step: 657
# Episode 868 reward: 294.6033483530282 | Rolling average: 120.92963360711896
# Current time step: 834
# Episode 869 reward: 295.70706582474395 | Rolling average: 121.02260668781804
# Current time step: 834
# Episode 870 reward: -21.992669446725486 | Rolling average: 121.11607081790737
# Current time step: 288
# Episode 871 reward: 295.36708761172497 | Rolling average: 121.03954207979793
# Current time step: 822
# Episode 872 reward: 293.59870385963274 | Rolling average: 121.13271554079842
# Current time step: 860
# Episode 873 reward: 294.16367606879885 | Rolling average: 121.22484480806274
# Current time step: 863
# Episode 874 reward: 296.74041275635676 | Rolling average: 121.31717733943525
# Current time step: 825
# Episode 875 reward: 297.9004572240069 | Rolling average: 121.41078632311559
# Current time step: 830
# Episode 876 reward: 296.0237502835425 | Rolling average: 121.50491414759607
# Current time step: 842
# Episode 877 reward: -120.25869531021984 | Rolling average: 121.59794124574954
# Current time step: 64
# Episode 878 reward: 300.01149951776875 | Rolling average: 121.46908848253379
# Current time step: 804
# Episode 879 reward: 301.35450288079545 | Rolling average: 121.56415898894232
# Current time step: 816
# Episode 880 reward: 297.98629828838307 | Rolling average: 121.65984304636216
# Current time step: 844
# Episode 881 reward: 294.86535454430503 | Rolling average: 121.75363371404408
# Current time step: 847
# Episode 882 reward: 0.5079306678660487 | Rolling average: 121.84566546355511
# Current time step: 406
# Episode 883 reward: -69.18939593631474 | Rolling average: 121.78119270330237
# Current time step: 255
# Episode 884 reward: -119.62032317333018 | Rolling average: 121.67977444061538
# Current time step: 84
# Episode 885 reward: -114.77116978979906 | Rolling average: 121.55169583254002
# Current time step: 55
# Episode 886 reward: 73.01343823128857 | Rolling average: 121.42632561205072
# Current time step: 662
# Episode 887 reward: 300.79985854290953 | Rolling average: 121.40065600050207
# Current time step: 835
# Episode 888 reward: 128.31307336993316 | Rolling average: 121.4957271200264
# Current time step: 713
# Episode 889 reward: -117.19497543699462 | Rolling average: 121.49933800257402
# Current time step: 90
# Episode 890 reward: 297.02988634555004 | Rolling average: 121.37297785782042
# Current time step: 876
# Episode 891 reward: 296.5082889848281 | Rolling average: 121.46591802104142
# Current time step: 873
# Episode 892 reward: 296.5107127236779 | Rolling average: 121.55848405539562
# Current time step: 892
# Episode 893 reward: 297.88842358914235 | Rolling average: 121.65095352086512
# Current time step: 867
# Episode 894 reward: 299.38939886838733 | Rolling average: 121.74405308244371
# Current time step: 849
# Episode 895 reward: 299.43473928391626 | Rolling average: 121.83784682361897
# Current time step: 844
# Episode 896 reward: 300.54643022888405 | Rolling average: 121.93156550037902
# Current time step: 830
# Episode 897 reward: 297.1931625403503 | Rolling average: 122.025771652662
# Current time step: 890
# Episode 898 reward: 296.2686773147022 | Rolling average: 122.11811081496441
# Current time step: 890
# Episode 899 reward: 267.36793635129715 | Rolling average: 122.20986559183467
# Current time step: 1271
# Episode 900 reward: 171.06522066094493 | Rolling average: 122.28630480761112
# Current time step: 850
# Episode 901 reward: 296.2110964120024 | Rolling average: 122.31197792121813
# Current time step: 879
# Episode 902 reward: 293.8617184121793 | Rolling average: 122.40345562689448
# Current time step: 883
# Episode 903 reward: 293.49666116180833 | Rolling average: 122.49360192699191
# Current time step: 889
# Episode 904 reward: 292.6914972202019 | Rolling average: 122.58346165333705
# Current time step: 886
# Episode 905 reward: 294.797031409576 | Rolling average: 122.67280410899193
# Current time step: 856
# Episode 906 reward: 152.28569911538426 | Rolling average: 122.7631580340841
# Current time step: 812
# Episode 907 reward: -46.44039442775032 | Rolling average: 122.77864730012884
# Current time step: 259
# Episode 908 reward: 284.46713902861035 | Rolling average: 122.68991156770731
# Current time step: 996
# Episode 909 reward: 291.982832088436 | Rolling average: 122.7747004709887
# Current time step: 904
# Episode 910 reward: 276.54239551522767 | Rolling average: 122.86333752264792
# Current time step: 1090
# Episode 911 reward: 286.7888083952369 | Rolling average: 122.94379776243461
# Current time step: 958
# Episode 912 reward: 285.1656001046041 | Rolling average: 123.0295356015936
# Current time step: 945
# Episode 913 reward: 285.941346354568 | Rolling average: 123.11433479850938
# Current time step: 908
# Episode 914 reward: 281.93569978892566 | Rolling average: 123.1994508526422
# Current time step: 939
# Episode 915 reward: 271.89605310130503 | Rolling average: 123.28238515198194
# Current time step: 1091
# Episode 916 reward: 52.02123553912267 | Rolling average: 123.35999020051945
# Current time step: 541
# Episode 917 reward: 275.8497351329181 | Rolling average: 123.32275703002811
# Current time step: 1031
# Episode 918 reward: 294.1336601126541 | Rolling average: 123.40232248548085
# Current time step: 844
# Episode 919 reward: 73.41833909840798 | Rolling average: 123.4913377814283
# Current time step: 590
# Episode 920 reward: 295.4064842237602 | Rolling average: 123.46524450436574
# Current time step: 943
# Episode 921 reward: 293.21910242645527 | Rolling average: 123.55479723338627
# Current time step: 917
# Episode 922 reward: 291.895573848162 | Rolling average: 123.64311805857787
# Current time step: 911
# Episode 923 reward: 170.6157922831316 | Rolling average: 123.73065835815622
# Current time step: 821
# Episode 924 reward: 290.5305278455595 | Rolling average: 123.755039603047
# Current time step: 918
# Episode 925 reward: 290.20801518794485 | Rolling average: 123.84172124974269
# Current time step: 939
# Episode 926 reward: 289.0263247394762 | Rolling average: 123.92814529854175
# Current time step: 931
# Episode 927 reward: 292.79835922081196 | Rolling average: 124.01386605629925
# Current time step: 894
# Episode 928 reward: 293.7794155717405 | Rolling average: 124.10145531066588
# Current time step: 907
# Episode 929 reward: 292.9749118257082 | Rolling average: 124.18946255146518
# Current time step: 829
# Episode 930 reward: 293.58717449688726 | Rolling average: 124.27696148836216
# Current time step: 867
# Episode 931 reward: 58.36950673294626 | Rolling average: 124.3646869873303
# Current time step: 585
# Episode 932 reward: 289.00729816972245 | Rolling average: 124.33051030154347
# Current time step: 1010
# Episode 933 reward: 294.01041783123736 | Rolling average: 124.41574673418746
# Current time step: 923
# Episode 934 reward: 282.8862184446452 | Rolling average: 124.50348324277361
# Current time step: 1055
# Episode 935 reward: 296.1757808836644 | Rolling average: 124.58537710792453
# Current time step: 924
# Episode 936 reward: 297.2025004778895 | Rolling average: 124.67405431917814
# Current time step: 888
# Episode 937 reward: 298.90860735783446 | Rolling average: 124.76317025211137
# Current time step: 877
# Episode 938 reward: 302.8240000968712 | Rolling average: 124.85307496925422
# Current time step: 838
# Episode 939 reward: 294.20138425857533 | Rolling average: 124.94490723196198
# Current time step: 987
# Episode 940 reward: 299.1701201422052 | Rolling average: 125.03219783383233
# Current time step: 912
# Episode 941 reward: 306.19159118477654 | Rolling average: 125.12195964945518
# Current time step: 824
# Episode 942 reward: 305.4264785713602 | Rolling average: 125.21524642510452
# Current time step: 836
# Episode 943 reward: 305.30571771937184 | Rolling average: 125.30804314608609
# Current time step: 809
# Episode 944 reward: 301.58363337443717 | Rolling average: 125.40068219630398
# Current time step: 879

# %% [markdown]
# # SOLVED!!!

# %%
#Calculate rolling average
import pandas as pd

# %%
df = pd.DataFrame(ep_reward)

# %%
df = df.rolling(window=100).mean()

# %%
df.plot()
plt.xlabel("Episode #")
plt.ylabel("Score")
plt.title("Rolling Score over episode number")
plt.legend()
plt.show()
